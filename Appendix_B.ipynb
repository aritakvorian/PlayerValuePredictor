# %% [markdown]
# # APPENDIX B

# %% [markdown]
# # Final Test Predictions

# %%
results = results.sort_values(by=['Error %'])
results = results.round(2)
results
# Out:
#                       Player  Predicted Value  Actual Value         Error  \
# 1440     Michael Gregoritsch     1,803,442.08   1,800,000.0      3,442.08
# 1013              Danny Ward     4,491,183.98   4,500,000.0      8,816.02
# 570          Conor Gallagher    11,774,980.49  11,700,000.0     74,980.49
# 1053        Boubakar Kouyate     4,534,744.93   4,500,000.0     34,744.93
# 439         Emile Smith-Rowe    15,911,893.68  16,200,000.0    288,106.32
# 631             Fran Beltran    11,049,597.16  10,800,000.0    249,597.16
# 513            Eddie Nketiah    13,863,461.65  13,500,000.0    363,461.65
# 1692            Artur Ionita       650,821.17     630,000.0     20,821.17
# 984            Junior Sambia     5,581,275.07   5,400,000.0    181,275.07
# 1235                 William     3,037,090.54   3,150,000.0    112,909.46
# 203            Adrien Rabiot    25,534,669.69  27,000,000.0  1,465,330.31
# 548       Geoffrey Kondogbia     13,484,070.6  12,600,000.0     884,070.6
# ...
